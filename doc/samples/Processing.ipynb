# %% [markdown]
# # The `processing` module

# %%
from fiontb.data.ftb import load_ftb
dataset = load_ftb("test-data/rgbd/sample1/")
frame = dataset[0]

from fiontb.processing import bilateral_depth_filter
proc_depth_image = bilateral_depth_filter(
    frame.depth_image, frame.depth_image > 0,
    filter_width=6, sigma_color=30, sigma_space=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(frame.depth_image)

# %%
plt.imshow(proc_depth_image)
