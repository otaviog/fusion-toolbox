# %% [markdown]
# # Loading data

# %% [markdown]
# Load one of TUMRGBD's scenes.

# %%
from fiontb.data.tumrgbd import load_tumrgbd

dataset = load_tumrgbd("rgbd_dataset_freiburg1_desk")

frame0 = dataset[0]

# %%
print(frame0)
# Out:
# Frame with shape (480x640) depth: True, RGB: True, segmentation: False, Normal: False

# %%
print(frame0.info)
# Out:
# Depth intrinsics: {Intrinsic matrix: tensor([[525.0000,   0.0000, 319.5000],
#         [  0.0000, 525.0000, 239.5000],
#         [  0.0000,   0.0000,   1.0000]]), radial distortion coefficients: [], image size: (640, 480)}, depth scale: 0.0002, depth bias: 0.0, timestamp: 1305031453.374112, Rigid Transformation: {{'matrix': tensor([[ 0.8758,  0.3425, -0.3400,  1.3137],
#         [ 0.4820, -0.5867,  0.6508,  0.8486],
#         [ 0.0234, -0.7338, -0.6789,  1.5192],
#         [ 0.0000,  0.0000,  0.0000,  1.0000]], dtype=torch.float64)}}

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(frame0.depth_image)

# %%
plt.imshow(frame0.rgb_image)
